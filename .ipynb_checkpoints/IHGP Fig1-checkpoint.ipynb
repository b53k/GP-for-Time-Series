# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
from scipy.io import loadmat
import scipy
import control

x = loadmat('x.mat')
y = loadmat('y.mat')

x = x['x'].reshape(-1)
y = y['y'].reshape(-1)

plt.scatter(x,y,marker='+', color = 'k')
plt.xlim([0,6])
plt.ylim([-1,1.2])
plt.xlabel('Input,$t$')
plt.ylabel('Output,$y$')
plt.show()

# %% [markdown]
# ## Full GP solution with parameter optimization

# %%
def matern32_kernel(X, Y, lengthscale=1.0, variance=1.0):
    distance = np.abs(X - Y.T)
    sqrt3 = np.sqrt(3.0)
    K = variance * (1.0 + sqrt3 * distance / lengthscale) * np.exp(-sqrt3 * distance / lengthscale)
    return K

def dk1(r, p):
    return (1 + np.sqrt(3) * np.abs(r)/p[1]) * np.exp(-np.sqrt(3)*np.abs(r)/p[1])

def dk2(r, p):
    return p[0]*(3 * r**2/p[1]**3) * np.exp(-np.sqrt(3)*np.abs(r)/p[1])

def gp_solve(params, x, y,  xt = None, opt = True):
    '''
    Args:
    params  - Log-Parameter (sigma2, magnSigma2, lengthscale)
    x       - Training inputs
    y       - Training outputs
    opt     - True if optimizing params; False if inferring
    
    Returns:
    (if xt is empty or not supplied)
    e       - Negative log-marginal likelihood
    eg      - its gradient

    (if xt is not empty)
    Eft     - Predicted mean
    Varft   - Predicted marginal variance
    Covft   - Predicted joint covariance matrix
    lb      - 95% confidence lower bound
    ub      - 95% confidence upper bound
    '''

    param = np.exp(params)
    sigma2 = param[0]
    magnSigma2 = param[1]
    lengthscale = param[2]

    K11 = matern32_kernel(x.reshape(-1,1), x.reshape(-1,1), lengthscale, magnSigma2) + np.eye(x.shape[0]) * sigma2

    try:
        L = np.linalg.cholesky(K11)
    except np.linalg.LinAlgError:
        jitter = 1e-9 * np.eye(x.shape[0])
        L = np.linalg.cholesky(K11 + jitter)


    x = x.reshape(-1,1)
    y = y.reshape(-1,1)

    vv = np.linalg.solve(L, y)
    alpha = np.linalg.solve(L.T, vv)

    if xt == None:
        xt = x

    if not opt:
        K21 = matern32_kernel(xt, x, lengthscale, magnSigma2)
        K22 = matern32_kernel(xt, xt, lengthscale, magnSigma2)
        
        # Solve for Mean
        Eft = K21 @ alpha
        
        # Solve for variance
        v = np.linalg.solve(L, K21.T)
        #vk = np.linalg.solve(L.T, v)
        #cov = K22 - K21 @ vk
        cov = K22 - v.T @ v

        # Marginal
        var = np.diag(cov)
        lb = Eft.ravel() -  1.96 * np.sqrt(var)
        ub = Eft.ravel() + 1.96 * np.sqrt(var)

        return Eft, var, cov, lb, ub
    
    else:
        # Evaluate negative log marginal likelihood
        beta1 = vv.T @ vv
        e = 0.5 * beta1 + np.sum(np.log(np.diag(L))) + 0.5*x.shape[0]*np.log(2*np.pi)

        # calculate gradient of log marginal likelihood
        eg = np.zeros(len(param))

        # Derivate w.r.t sigma2 i.e. noise variance
        invk = np.linalg.solve(L.T, np.linalg.solve(L, np.eye(x.shape[0])))
        eg[0] = 0.5 * np.trace(invk) - 0.5 * (alpha.T @ alpha)[0][0]

        # Derivative w.r.t. rest of the parameters
        for i in range(1, len(param)-1):
            r = x[:, None] - x[None,:]
            dK = dk1(r, param[1:]) if i == 1 else dk2(r, param[1:])
            dK = dK.reshape(dK.shape[0],dK.shape[1])
            eg[i] = 0.5 * np.sum(invk * dK) - 0.5 * (alpha.T @ (dK @ alpha))[0][0]
            
        return e[0][0], eg

# %%
from scipy.optimize import minimize

param = np.array([0.1, 0.1, 0.1])

def objective_function(w):
    return gp_solve(w,x,y,xt = None, opt = True)

result = minimize(fun = objective_function, x0 = np.log(param), method = 'Powell', jac = True, options={'disp': True})  # Nelder-Mead, Powell, BFGS, CG, Newton-CG

w1 = result.x
ll = result.fun

Eft1, var1, _, lb1, ub1 = gp_solve(params = w1, x = x, y = y, xt = None, opt = False)

plt.figure()
plt.scatter(x,y,marker='+', color = 'k')
plt.plot(x, Eft1, label = 'Full GP Mean', color = 'r', linestyle = '--', linewidth = 0.9)
plt.plot(x, lb1, color = 'r', linestyle = '--', linewidth = 0.8)
plt.plot(x, ub1, color = 'r', linestyle = '--', linewidth = 0.8)
plt.fill_between(x.flatten(), lb1, ub1, color = 'gray', label = '95% Quantile', alpha = 0.5)


plt.xlim([0,6])
plt.ylim([-1,1.2])
plt.xlabel('Input,$t$')
plt.ylabel('Output,$y$')
plt.legend()
plt.show()
# Out:
# /home/bipin/.local/lib/python3.10/site-packages/scipy/optimize/_minimize.py:560: RuntimeWarning: Method Powell does not use gradient information (jac).
#   warn('Method %s does not use gradient information (jac).' % method,
# Optimization terminated successfully.
#          Current function value: 49.235568
#          Iterations: 4
#          Function evaluations: 126

# %% [markdown]
# ## IHGP Implementation

# %%
def cf_matern_to_ss(magnSigma2, lengthscale, opt = False):
    # Form State Space Model
    Lambda = np.sqrt(3)/lengthscale
    F = np.array([[0, 1],[-Lambda**2, -2*Lambda]])
    L = np.array([0,1]).reshape(2,1)
    Qc = 12 * (np.sqrt(3)/lengthscale**3) * magnSigma2
    H = np.array([1, 0]).reshape(1,2)
    Pinf = magnSigma2 * np.diag([1, 3/lengthscale**2])

    if opt == True:
        # Calculate Derivatives
        dFmagnSigma2 = np.zeros(shape = (F.shape[0], F.shape[1]))
        dFlengthscale = np.array([[0, 0],[6/lengthscale**3, 2*np.sqrt(3)/lengthscale**2]])
        
        dQcmagnSigma2 = 12 * np.sqrt(3)/lengthscale**3
        dQclengthscale = -3 * 12 * np.sqrt(3)/lengthscale**4 * magnSigma2

        dPinfmagnSigma2 = np.array([[1, 0], [0, 3 / lengthscale**2]])
        dPinflengthscale = magnSigma2 * np.array([[0, 0], [0, -6 / lengthscale**3]])

        # stack all derivates
        dF = np.zeros((2, 2, 2))
        dQc = np.zeros((1, 1, 2))
        dPinf = np.zeros((2, 2, 2))

        dF[0] = dFmagnSigma2
        dF[1] = dFlengthscale

        dQc[0][0][0] = dQcmagnSigma2
        dQc[0][0][1] = dQclengthscale

        dPinf[0] = dPinfmagnSigma2
        dPinf[1] = dPinflengthscale

        return F, L, Qc, H, Pinf, dF, dQc, dPinf
    
    else:
        return F, L, Qc, H, Pinf

ss = lambda x, p, f: cf_matern_to_ss(p[0], p[1], f)

def ihgpr(w, x, y, ss, xt, opt = False):
    # Combine observations and test points
    xall = np.concatenate([x.flatten(), xt.flatten()])
    yall = np.concatenate([y.flatten(), np.nan * np.ones(len(xt))])

    # Make sure points are unique and are in ascending order
    xall, sort_ind = np.unique(xall, return_index = True)
    yall = yall[sort_ind]

    # Only return test indices
    return_ind = np.arange(len(xall)) + 1
    return_ind = return_ind[-len(xt):]

    if np.std(np.diff(xall)) > 1e-12:
        raise Exception('This function only accepts equidistant time-stamps only')
    
    param = np.exp(w)
    
    d = len(x)
    sigma2 = param[0]

    # Form State-Space Model
    F, L, Qc, H, Pinf, dF, dQc, dPinf = ss(x, param[1:], f=True)

    # Concatenate Derivatives
                                                                                        # TODO: Complete this block if needed.

    # Stationary Stuffs
    dt = xall[1] - xall[0]
    A = scipy.linalg.expm(F * dt)
    Q = Pinf - A @ Pinf @ np.transpose(A)
    Q = (Q + Q.T)/2
    R = sigma2

    try:
        Pp = scipy.linalg.solve_discrete_are(A.T, H.T, Q, R)
    except Exception as e:
        print (f'Unable to solve DARE: {e}')

    # Innovation variance
    S = H @ Pp @ H.T + R

    # Stationary Gain
    K = Pp @ H.T / S[0][0]

    # Pre-calculate
    AKHA = A - K @ H @ A

    # Filtering and Smoothing
    if not opt:
        # set initial state
        m = np.zeros((F.shape[0], 1))
        PF = Pp - K @ H @ Pp

        # Allocate space for results
        MS = np.zeros((F.shape[0], len(yall)))
        PS = np.zeros((F.shape[0], F.shape[1], len(yall)))

        # Filter Forward Recursion
        for k in range(len(yall)):
            if ~np.isnan(yall[k]):
                m = AKHA @ m + K * yall[k]             # O(m^2) Complexity

                # Store Estimate
                MS[:, k] = m.T                   
                PS[:,:,k] = PF                         # Same for all points
            else:
                m = A @ m
                MS[:, k] = m.T
                PS[:,:,k] = Pinf
        
        # Backward Smoother
        GS = np.zeros([2, 2, len(yall)])               # Allocate space for Smoother Gain
        Lo = np.linalg.cholesky(Pp)
        X = np.linalg.solve(Lo.T, A.T)
        Y = np.linalg.solve(Lo, X)
        G = PF @ Y

        G = PF @ A.T @ np.linalg.inv(L.T) @ np.linalg.inv(L)

        # Solve Riccati Equation
        QQ = PF - G @ Pp @ G.T
        QQ = (QQ + QQ.T)/2
        P = scipy.linalg.solve_discrete_are(G.T, np.zeros_like(G), QQ, Q)
        #P, _, _ = control.dare(G.T, np.zeros_like(G), QQ, Q)
        print (P)
        PS[:,:,-1] = P

        # RTS Smoothing
        m = m.T.reshape(2)
        for k in range(MS.shape[1] - 2, -1, -1):  # MS.shape[1] gives the number of columns in MS
            # Backward iteration
            m = MS[:, k] + G @ (m - A @ MS[:, k])
            # Store estimate
            MS[:, k] = m
            PS[:, :, k] = P
            GS[:, :, k] = G
        
        # Return smoother mean and marginal variance
        Eft = (H @ MS).T
        Varft = []
        for i in range(len(MS[1])):
            Varft.append( H @ PS[:, :, i] @ H.T)

        return Eft.reshape(-1), np.array(Varft).reshape(-1)
    
    else:
        # Optimize Hyperparameters
        beta1 = vv

# %%
eft, var = ihgpr([0.1,0.1,0.1], x, y, ss,x,opt=False)
# Out:
# [[ 8.65377119e-02 -7.12483173e-16]
#  [-7.12483173e-16  1.39567956e+00]]

# %%
Pp = np.array([[0.0734, 0.2436], [0.2436, 27.6944]])
PF = np.array([[0.0423, 0.1405], [0.1405, 27.3522]])
A = np.array([[0.7175, 0.0212], [-6.3642, -0.0174]])
L = np.linalg.cholesky(Pp)

# %%
Lo = np.linalg.cholesky(Pp)
X = np.linalg.solve(Lo.T, A.T)
Y = np.linalg.solve(Lo, X)
G = PF @ Y
G
# Out:
# array([[ 1.74543599e-01, -1.55453481e+00],
#        [-4.47389087e+01,  3.98861658e+02]])

# %%
G = PF @ A.T @ np.linalg.inv(L.T) @ np.linalg.inv(L)
G
# Out:
# array([[ 0.50125798, -0.01421792],
#        [ 9.7214859 , -0.13498225]])

# %%
A = np.array([[2, 3, 1], [0, 8, 4], [1, 1, 0]])
B = np.array([[7, 6, 6], [1, 0, 5], [9, 0, 4]])

A @ np.linalg.inv(B)
# Out:
# array([[ 0.5       , -0.29268293, -0.13414634],
#        [ 1.33333333,  0.03252033, -1.04065041],
#        [ 0.16666667, -0.20325203,  0.00406504]])

# %%
import scipy

# Data
#data = triangle_sorted[triangle_sorted[:, 0].argsort()]
yall = y
xall = x

#xall = np.linspace(0,30,100)
#yall = np.sin(xall)

# Define the LTI SDE model: Matern 3/2
ell = 0.1
lambda_ = np.sqrt(3) / ell
mag_sigma_2 = 0.1       # Magnitude of state covariance, can also tune this 
sigma_2 = 0.1      # Observation noise


# Form State-Space Model
F = np.array([[0, 1], [-lambda_**2, -2 * lambda_]])
L = np.array([0, 1]).reshape(2,1)
Qc = 12*(np.sqrt(3)/(ell**3)) * mag_sigma_2     # Diffusion Matrix
H = np.array([1, 0]).reshape(1,2)
Pinf = mag_sigma_2 * np.diag([1, 3/ell**2])  # State Covariance

# This assumes prior covariance function to be stationary
dt = 0.06060606060606061
A = scipy.linalg.expm(F*dt)
Q = Pinf - A @ Pinf @ A.T
Q = (Q + Q.T)/2
R = sigma_2

try:
    Pp = scipy.linalg.solve_discrete_are(A.T, H.T, Q, R)
except Exception as e:
    print (f'Unable to solve DARE: {e}')


# Innovation variance
s_hat = H @ Pp @ H.T + R

# Stationary Gain
K = Pp @ H.T / s_hat[0][0]

# Pre-calculate
AKHA = A - K @ H @ A


##### Filtering
# Set initial state
m = np.zeros((F.shape[0],1))
PF = Pp - K @ H @ Pp

# Allocate space for results
MS = np.zeros((2, len(yall)))
PS = np.zeros((2,2, len(yall)))

# Filter Recursion - Forward
# For now all the y values are training points
for k in range(len(yall)):
    m = AKHA @ m + K * yall[k]                # O(m^2) Complexity

    # Store Estimate
    MS[:, k] = m.T                   
    PS[:,:,k] = PF                   # Same for all points

##### Backward Smoother
GS = np.zeros([2, 2, len(yall)])       # Allocate space for Smoother Gain

# TODO: Check this implementation if you've got weird result
#mat = A @ PF @ A.T + Q
L = np.linalg.cholesky(Pp)
G = PF @ A.T @ np.linalg.inv(L.T) @ np.linalg.inv(L)
#G = np.linalg.lstsq(Pp.T, A @ PF.T, rcond = None)[0].T        # Pp = A @ PF @ A.T + Q

# Solve Riccati Equation
QQ = PF - G @ Pp @ G.T
QQ = (QQ + QQ.T)/2

#P = scipy.linalg.solve_discrete_are(G.T, 0*G, QQ)
P = scipy.linalg.solve_discrete_are(G.T, np.zeros_like(G), QQ, Q)
#P = np.array([[0.0022, 0.0000],[0.0000, 0.2166]])
PS[:,:,-1] = P

####################
# For this data 
# P should be: [0.0022        0.0000]
#              [0.0000        0.2166]
###################
# RTS Smoothing
m = m.T.reshape(2)
for k in range(MS.shape[1] - 2, -1, -1):  # MS.shape[1] gives the number of columns in MS
    # Backward iteration
    m = MS[:, k] + G @ (m - A @ MS[:, k])
    # Store estimate
    MS[:, k] = m
    PS[:, :, k] = P
    GS[:, :, k] = G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 80
#      77 QQ = (QQ + QQ.T)/2
#      79 #P = scipy.linalg.solve_discrete_are(G.T, 0*G, QQ)
# ---> 80 P = scipy.linalg.solve_discrete_are(G.T, np.zeros_like(G), QQ)
#      81 #P = np.array([[0.0022, 0.0000],[0.0000, 0.2166]])
#      82 PS[:,:,-1] = P
#
# TypeError: solve_discrete_are() missing 1 required positional argument: 'r'

# %%
import scipy

# Data
yall = y
xall = x

#xall = np.linspace(0,30,100)
#yall = np.sin(xall)

# Define the LTI SDE model: Matern 3/2
ell = 1.5
mag_sigma_2 = 1.0**2       # Magnitude of state covariance, can also tune this 
sigma_2 = 0.1 ** 2      # Observation noise

def IHGP(xall, yall, ell, sigma_2, mag_sigma_2):
    lambda_ = np.sqrt(3) / ell
    # Form State-Space Model
    F = np.array([[0, 1], [-lambda_**2, -2 * lambda_]])
    L = np.array([0, 1]).reshape(2,1)
    Qc = 12*(np.sqrt(3)/(ell**3)) * mag_sigma_2     # Diffusion Matrix
    H = np.array([1, 0]).reshape(1,2)
    Pinf = mag_sigma_2 * np.diag([1, 3/ell**2])  # State Covariance

    # This assumes prior covariance function to be stationary
    #dt = 0.30303030303030
    dt = 0.06165
    A = scipy.linalg.expm(F*dt)
    Q = Pinf - A @ Pinf @ A.T
    Q = (Q + Q.T)/2
    R = sigma_2

    try:
        Pp = scipy.linalg.solve_discrete_are(A.T, H.T, Q, R)
    except Exception as e:
        print (f'Unable to solve DARE: {e}')


    # Innovation variance
    s_hat = H @ Pp @ H.T + R

    # Stationary Gain
    K = Pp @ H.T / s_hat[0][0]

    # Pre-calculate
    AKHA = A - K @ H @ A


    ##### Filtering
    # Set initial state
    m = np.zeros((F.shape[0],1))
    PF = Pp - K @ H @ Pp


    ll = (0.5 * np.log(2*np.pi) + 0.5 * np.log(s_hat[0][0])) * len(yall)
    # Filter Recursion - Forward
    # For now all the y values are training points
    for k in range(len(yall)):
        vi = yall[k].flatten() - (H @ A @ m).flatten()
        ll += 0.5 * vi**2/s_hat[0][0]
        m = AKHA @ m + K * yall[k]                # O(m^2) Complexity

    return ll[0]

# %%
# Contour Plot
L = np.linspace(1e-3, 1e3, 100)
S = np.linspace(1e-3, 1e3, 100)
σ, ℓ = np.meshgrid(L, S)

func_val = np.zeros_like(σ)
for i in range(σ.shape[0]):
    for j in range(ℓ.shape[0]):
        #func_val[i,j] = neg_ll(t,y,matern32_kernel, L[j], S[i])
        func_val[i,j] = IHGP(xall, yall, L[j], 0.1**2, S[i])

plt.contourf(σ, ℓ, func_val, cmap = 'plasma')
plt.title('IHGP/MIHGP')
plt.xlabel('length-scale $\ell$')
plt.ylabel('$\sigma^2$')
plt.xscale('log')
plt.yscale('log')
plt.colorbar()
plt.show()
# Out:
# /home/bipin/.local/lib/python3.10/site-packages/scipy/linalg/_basic.py:1679: RuntimeWarning: invalid value encountered in cast
#   ps = ps.astype(int, copy=False) - 1

# %%
data[:,0]

def get_kalman_likelihood(data, ell, mag_sigma_2):
    # Define the LTI SDE model: Matern 3/2
    lambda_ = np.sqrt(3) / ell
    sigma_2 = 0.1 ** 2      # Observation noise

    F = np.array([[0, 1], [-lambda_**2, -2 * lambda_]])
    L = np.array([0, 1]).reshape(2,1)
    Qc = 4 * lambda_**3 * mag_sigma_2     # Process Noise
    H = np.array([1, 0]).reshape(1,2)
    Pinf = mag_sigma_2 * np.diag([1, lambda_**2])  # State Covariance

    # Initialize
    m = np.zeros((F.shape[0], 1))
    P = copy.deepcopy(Pinf)

    # Plae holders
    MF = np.zeros((F.shape[0], len(data)))                # Updated Filter Mean
    PF = np.zeros((F.shape[0], F.shape[1], len(data)))    # Updated Filter Covariance
    MP = np.zeros((F.shape[0], len(data)))                # Predicted Filter Mean
    PP = np.zeros((F.shape[0], F.shape[1], len(data)))    # Predicted Filter Covariance
    GS = np.zeros((F.shape[0], F.shape[1], len(data)))    # Smoother Gain

    for k in range(0, len(data[:,0])):
        if k == 0:
            dt = data[0,0]
        else:
            dt = data[k,0] - data[k-1,0]
        
        A = scipy.linalg.expm(F * dt)
        Q = Pinf - A @ Pinf @ A.T
        Q = (Q + Q.T)/2     

        # kalman prediciton
        mp = A @ m
        Pp = A @ P @ A.T + Q

        Gs = np.linalg.lstsq(Pp.T, (P @ A.T).T, rcond = None)[0].T

        v = (data[k,1] - H @ mp)
        S = H @ Pp @ H.T + sigma_2
        K = np.linalg.lstsq(S.T, (Pp @ H.T).T, rcond = None)[0].T
        m = mp + K * v
        P = Pp - K @ S @ K.T

        MF[:, k] = m.T
        PF[:, :, k] = P
        MP[:, k] = mp.T
        PP[:, :, k] = Pp
        GS[:, :, k] = Gs

    #TT = len(data)
    #MS = copy.deepcopy(MF)
    #PS = copy.deepcopy(PF)
    #ms = MS[:, -1]
    #Ps = PS[:,:,-1]

    #for j in range(TT-2, -1, -1):
    #    ms = MF[:, j] + GS[:, :, j+1] @ (ms - MP[:, j+1])
    #    Ps = PF[:,:,j] + GS[:,:,j+1] @ (Ps - PP[:,:,j+1]) @ (GS[:,:,j+1]).T
    #    MS[:,j] = ms
    #    PS[:,:,j] = Ps


    # Compute Likelihood 
    nll = 0
    for k in range(0,len(data)-1):
        if k == 0:
            dt = data[0,0]
        else:
            dt = data[k,0] - data[k-1,0]
        
        A_k = scipy.linalg.expm(F * dt)

        delta_xk = MF[:,k+1].T - A_k @ MF[:,k].T

        def integrand(tau, i, j):
            exp1 = scipy.linalg.expm(F * (dt - tau))
            exp2 = scipy.linalg.expm(F.T * (dt - tau))
            variance = L.reshape(-1,1) @ Qc.reshape(-1,1) @ (L.reshape(-1,1)).T
            return (exp1 @ variance @ exp2)[i, j]
        
        Sigma_k = np.zeros_like(F)
        for n in range(F.shape[0]):
            for m in range(F.shape[1]):
                Sigma_k[n,m], _ = quad(integrand, 0, dt, args = (n, m))

        #Cholesky
        #Lo = np.linalg.cholesky(Sigma_k)
        #a = np.linalg.solve(Lo.T, np.linalg.solve(Lo,delta_xk))      # a = Sigma_k_inv @ delta_xk

        a = np.linalg.lstsq(Sigma_k, delta_xk, rcond = None)[0]
    
        nll += 0.5 * np.log(det(2 * np.pi * Sigma_k))
        nll += 0.5 * delta_xk.T @ a

    return nll

# %%
nll = get_kalman_likelihood(data, ell = 1.5, mag_sigma_2=1.0)

# %%
# Contour Plot
L = np.linspace(1e-3, 1e3, 10)
S = np.linspace(1e-3, 1e3, 10)
σ, ℓ = np.meshgrid(L, S)

func_val = np.zeros_like(σ)
for i in range(σ.shape[0]):
    for j in range(ℓ.shape[0]):
        #func_val[i,j] = neg_ll(t,y,matern32_kernel, L[j], S[i])
        #func_val[i,j] = IHGP(xall, yall, L[j], 0.1**2, S[i])
        func_val[i,j]= get_kalman_likelihood(data, ell = L[j], mag_sigma_2=S[i])


plt.contourf(σ, ℓ, func_val, cmap = 'plasma')
plt.title('Book--Sarka & Solin')
plt.xlabel('length-scale $\ell$')
plt.ylabel('$\sigma^2$')
plt.xscale('log')
plt.yscale('log')
plt.colorbar()
plt.show()
